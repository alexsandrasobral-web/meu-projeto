# %%
salbase=float(input("Insira o valor do salário base:"))
vantagens=float(input("Insira os benefícios:"))
desconto=float(input"Insira os descontos:")
salfinal=salbase+vantagens-desconto
print(salfinal)
# Out:
# A soma dos valores é: 16
# A diferença dos valores é: -7
